# %%
from fastai.vision import *

# %%
folder = 'minor'
file = '/home/deniz/Code/KaggleData/age_group_data/minors.txt'

# %%
folder = 'adult'
file = '/home/deniz/Code/KaggleData/age_group_data/adult.txt'

# %%
folder = 'senior'
file = '/home/deniz/Code/KaggleData/age_group_data/seniors.txt'

# %% [markdown]
# run this as needed to make the folders

# %%
path = Path('/home/deniz/Code/KaggleData/age_group_data/people')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/home/deniz/Code/KaggleData/age_group_data/people/minor'),
#  PosixPath('/home/deniz/Code/KaggleData/age_group_data/people/senior'),
#  PosixPath('/home/deniz/Code/KaggleData/age_group_data/people/adult')]

# %%
classes = ['minor','adult','senior']

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# remove images that can't be opened

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# minor
# adult
# senior

# %% [markdown]
# ## View Data

# %%
# same validation set, same vlaidation set to make sure the same hyperpramether works well 
np.random.seed(42)
# create the validation set randomly and automatically 
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['adult', 'minor', 'senior']

# %%
data.show_batch(rows=3, figsize=(7,8))
